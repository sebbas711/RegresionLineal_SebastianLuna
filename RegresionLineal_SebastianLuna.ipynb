# %%
#Juan Sebastian Luna Sanchez
#Analisis de Datos 
#UNAD
# Cargamos a nuestro entorno de trabajo las librerias necesarias.

import matplotlib.pyplot as plt
from sklearn import linear_model #usando sklear para saber los valores optimos
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/sluna/Documents/Universidad/9no Semestre/Analisis de Datos/Tarea 2/Dataset Regresión Lineal/data.csv", sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.columns
data.info
data.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
data.plot.scatter(x="metro", y="precio")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
metros=data["metro"].values.reshape((-1,1))

# %%
modelo=regresion.fit(metros,data["precio"])

print ("Interseccion (b)", modelo.intercept_)
print ("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
entrada= [[5],[10],[15],[20],[25]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [389.48571429 417.71428571 445.94285714 474.17142857 502.4       ]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos Originales')
plt.scatter(entrada, predicciones, color='purple')
plt.plot(entrada, predicciones, color='black', label='Linea de Regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
